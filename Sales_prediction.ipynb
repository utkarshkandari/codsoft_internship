# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
raw_df=pd.read_csv("advertising.csv")
raw_df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
print(f"We have {raw_df.shape[0]} rows and {raw_df.shape[1]} columns in the datset")
# Out:
# We have 200 rows and 4 columns in the datset

# %%
x=raw_df[['TV','Radio','Newspaper']]
y=raw_df['Sales']

# %%
ax = sns.scatterplot(x='value', hue='legends', y='Sales', data=raw_df.melt(value_vars=['TV','Radio','Newspaper'], id_vars='Sales', var_name='legends'))

# %%
# directly splitting the dataset into train and test 
x_train,x_test,y_train,y_test=train_test_split(raw_df['TV'],raw_df['Sales'],test_size=0.25,random_state=365)

# %%
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 2
#       1 reg=LinearRegression()
# ----> 2 reg.fit(x_train,y_train)
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:648, in LinearRegression.fit(self, X, y, sample_weight)
#     644 n_jobs_ = self.n_jobs
#     646 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 648 X, y = self._validate_data(
#     649     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650 )
#     652 sample_weight = _check_sample_weight(
#     653     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     654 )
#     656 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     657     X,
#     658     y,
#    (...)
#     661     sample_weight=sample_weight,
#     662 )
#
# ...

# %%
#pred=reg.fit_transform(y_train,y_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 pred=reg.fit_transform(y_train,y_test)
#
# AttributeError: 'LinearRegression' object has no attribute 'fit_transform'
